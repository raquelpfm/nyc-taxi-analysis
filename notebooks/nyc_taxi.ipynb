# %% [markdown]
# # Análise de Corridas de Taxi (NYC Yellow Taxi - Q1 2016)
#
# ## 1. Introdução e Contexto
# A cidade de Nova York possui um dos sistemas de transporte mais icônicos e complexos do mundo. No centro desta rede estão os Yellow Taxis, geridos pela Taxi & Limousine Commission (TLC). Esta análise debruça-se sobre os dados do primeiro trimestre de 2016, um período crucial onde o setor tradicional enfrentava a crescente concorrência das plataformas tecnológicas, como o Uber. Estudar esses dados permite-nos compreender não apenas o fluxo de transporte, mas também o comportamento de consumo (gorjetas), o impacto da geografia urbana na receita e a eficiência logística das rotas mais viciadas.
#
# O conjunto de dados original é classificado como Big Data, apresentando desafios significativos de processamento:
# - Aproximadamente 35 milhões de corridas registradas apenas nestes três meses.
# - Alta complexidade, pois cada registro contém 19 atributos.
# - Com um volume superior a 5GB de dados brutos, o carregamento integral é inviável em máquinas convencionais.
#
# Para contornar este obstáculo, foi implementada uma estratégia de amostragem aleatória estratificada, extraindo 500.000 amostras por mês. Esta técnica garante a integridade estatística, permitindo que as conclusões aqui apresentadas reflitam com precisão as tendências do universo total de dados, otimizando ao mesmo tempo a performance computacional.
#
# ### Dicionário de Dados
# Para garantir a precisão da análise, define-se abaixo o significado de cada coluna presente no datasert, conforme a documentação oficial da NYC Taxi and Limousine Commission:
# | Coluna | Descrição |
# | ------ | --------- |
# | VendorID | Código indicador do fornecedor de tecnologia (1 = Creative Mobile Technologies; 2 = VeriFone Inc.) |
# | tpep_pickup_datetime | Data e hora exata em que o taxímetro foi acionado (início da corrida) |
# | tpep_dropoff_datetime | Data e hora exata em que o taxímetro foi desligado (fim da corrida) |
# | passenger_count | Número de passageiros no veículo, conforme inserido pelo motorista |
# | trip_distance | Distância total da viagem percorrida em milhas, registrada pelo taxímetro |
# | RatecodeID | Código da tarifa final aplicada (conforme detalhado na seção de tarifação) |
# | store_and_fwd_flag | Indica se o registro foi armazenado na memória do veículo antes do envio (Y) ou se foi enviado imediatamente (N) |
# | pickup_longitude | Longitude geográfica do ponto onde o passageiro embarcou |
# | pickup_latitude | Latitude geográfica do ponto onde o passageiro embarcou |
# | dropoff_longitude | Longitude geográfica do ponto onde o passageiro desembarcou |
# | dropoff_latitude | Latitude geográfica do ponto onde o passageiro desembarcou |
# | payment_type | Código numérico da forma de pagamento (1 = Cartão de crédito; 2 = Dinheiro; 3 = Sem cobrança; 4 = Disputa) |
# | fare_amount | Valor da tarifa calculado pelo tempo e distância percorrida |
# | extra | Sobretaxas diversas, como taxas de horário de pico ($0.50 ou $1.00) |
# | mta_tax | Imposto de $0.50 da Metropolitan Transportation Authority |
# | tip_amount | Valor da gorjeta, preenchido automaticamente apenas para pagamentos com cartão |
# | tolls_amount | Valor total pago em pedágios durante a viagem |
# | improvement_surcharge | Taxa de $0.30 destinada a melhorias na infraestrutura e acessibilidade |
# | total_amount | Valor total cobrado ao passageiro (inclui todas as taxas e gorjetas via cartão) |
# | mes_origem | Variável personalizada que identifica o mês do arquivo original (01, 02 ou 03) |

# %% [markdown]
# ## 2. Objetivos da Investigação
#
# Esta análise exploratória foi estruturada para responder a perguntas fundamentais de negócio e logística:
#
# **1. Dinâmica Temporal:**
# Quais são os períodos de "pico" real onde a procura excede a oferta? Como o comportamento muda entre dias úteis e fins de semana?
#
# **2. Arquitetura Financeira:**
# Como a distância percorrida e a duração da viagem influenciam a tarifa final? Existe um padrão cultural identificável na atribuição de gorjetas?
#
# **3. Inteligência Geográfica:**
# Onde estão localizados os principais centros de geração de receita? Conseguimos identificar "corredores de lucro" que ligam pontos importantes como aeroportos e centros financeiros?
#
# **4. Qualidade e Saneamento:**
# Identificar e isolar anomalias (outliers) que possam distorcer a realidade operacional (por exemplo: corridas de 0 minutos ou tarifas negativas).

# %% [markdown]
# ## 3. Configuração do Ambiente e Ferramentas
# Antes de iniciar a manipulação dos dados, o ambiente de trabalho foi preparado importando as bibliotecas que compõem as ferramentas analíticas. O ecossistema Python oferece bibliotecas robustas que serão utilizadas da seguinte forma:
#
# **Pandas e NumPy:** Pilares para a manipulação de estruturas de dados complexas e operações matemáticas de alta performance.
#
# **Matplotlib e Seaborn:** Utilizadas para a construção de visualizações estáticas e estilização de gráficos.
#
# **Plotly:** Biblioteca fundamental para a criação de mapas de calor e gráficos interativos, permitindo uma exploração mais profunda dos dados geográficos da cidade.
#
# **OS e Subprocess:** Ferramentas de sistema utilizadas para gerir diretórios e executar comandos de terminal de forma integrada ao fluxo de dados.
#
# Também foram definidas configurações globais de visualização (`sns.set_theme` e `plt.rcParams`) para garantir que todos os gráficos mantenham uma identidade visual coesa, com fontes e tamanhos padronizados, facilitando a leitura e a interpretação dos resultados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import os
import subprocess

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (13, 5)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 4. Ingestão de Dados e Amostragem Aleatória
# O maior desafio técnico deste projeto é o volume de dados. O conjunto completo contém mais de 34 milhões de registros, e carregar esses arquivos CSV diretamente via Pandas consumiria toda a memória RAM disponível. Para resolver este problema, foi implementada uma técnica de amostragem por leitura seletiva. O processo segue esses passos:
#
# 1. Contagem de linhas via sistema operacional: Em vez de abrir o arquivo no Python para contar as linhas, é utilizado o comando de terminal `wc -l` através da biblioteca `subprocess`. Isso permite saber o tamanho exato do arquivo rapidamente.
# 2. Cálculo de amostragem antecipada: É definido um alvo de 500.000 amostras por arquivo. O `numpy` foi utilizado para gerar uma lista de números de linhas que devem ser puladas.
# 3. Leitura seletiva: Ao passar essa lista, o Pandas ignora as linhas desnecessárias e carrega apenas a amostra aleatória diretamente para a memória.
# 4. Rastreabilidade: Adicionamos a coluna `mes_origem` para identificar de qual arquivo cada registro veio, garantindo que possam ser realizadas análises mensais comparativas posteriormente.
#
# Essa abordagem garante que o DataFrame final seja estatisticamente representativo, mas leve o suficiente para ser processado rapidamente.

# %%
AMOSTRA_POR_ARQUIVO = 500_000

pasta = '../data/'
arquivos_csv = sorted([
    f for f in os.listdir(pasta) 
    if f.startswith('yellow_tripdata_2016') 
    and f.endswith('.csv')
])

dfs = []
for arquivo in arquivos_csv:

    # contar total de linhas no arquivo
    resultado = subprocess.run(
        ['wc', '-l', pasta + arquivo], 
        capture_output=True, text=True
    )
    total_linhas = int(resultado.stdout.strip().split()[0]) - 1  # subtrair 1 para o cabeçalho
    print(f"{arquivo} — {total_linhas:,} linhas")

    # calcular quais linhas pular para amostra aleatória
    linhas_pular = sorted(
        np.random.choice(
            range(1, total_linhas + 1),  # linhas começam em 1 por causa do cabeçalho
            size=total_linhas - AMOSTRA_POR_ARQUIVO,
            replace=False
        )
    )
    
    # carregar apenas as linhas selecionadas
    df_temp = pd.read_csv(
        pasta + arquivo, 
        skiprows=linhas_pular,
        low_memory=False
    )
    df_temp['mes_origem'] = arquivo.split('-')[1].replace('.csv', '')
    dfs.append(df_temp)
    print(f"Amostra carregada - {len(df_temp):,} linhas\n")
# Out:
# yellow_tripdata_2016-01.csv — 10,906,858 linhas
# Amostra carregada - 500,000 linhas
#
# yellow_tripdata_2016-02.csv — 11,382,049 linhas
# Amostra carregada - 500,000 linhas
#
# yellow_tripdata_2016-03.csv — 12,210,952 linhas
# Amostra carregada - 500,000 linhas

# %% [markdown]
# ## 5. Consolidação do Dataset Trimestral
#
# Após o carregamento das amostras individuais de janeiro, fevereiro e março, é feita a unificação dos dados em um único dataframe global. Esta etapa é fundamental para realizar análises que cruzem tendências ao longo de todo o primeiro trimestre de 2016.
#
# Para isso, utiliza-se a função `pd.concat()`, que realiza o empilhamento vertical dos objetos contidos na lista de amostras. Como os arquivos mensais da TLC possuem estruturas de colunas idênticas, a concatenação ocorre de forma consistente, preservando o alinhamento das variáveis entre os diferentes meses.
#
# O parâmetro `ignore_index=True` é aplicado para assegurar a integridade da indexação do novo dataset. Visto que cada dataframe mensal possui seu próprio índice iniciando do zero, a união simples iria manter esses índices originais, gerando entradas duplicadas. Ao definir esse parâmetro como verdadeiro, o Pandas descarta os índices antigos e gera uma nova sequência numérica contínua, evitando erros lógicos em operações futuras.

# %%
df = pd.concat(dfs, ignore_index=True)
print(f"DataFrame final: {len(df):,} linhas")

df.head()
# Out:
# DataFrame final: 1,500,000 linhas
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:32   2016-01-01 00:13:20                5
# 1         1  2016-01-01 00:00:40   2016-01-01 00:14:03                1
# 2         2  2016-01-01 00:00:45   2016-01-01 00:09:17                6
# 3         2  2016-01-01 00:00:49   2016-01-01 00:09:01                1
# 4         1  2016-01-01 00:01:11   2016-01-01 00:08:06                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           3.60        -73.996948        40.720501           1
# 1           4.30        -73.966179        40.762222           1
# 2           1.85        -73.994202        40.726471           1
# 3           1.22        -73.982140        40.771687           1
# 4           1.50        -74.003487        40.741570           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# ## 6. Data Profiling
#
# Este é o processo de examinar os dados disponíveis e coletar estatísticas e resumos informativos. É uma etapa crucial para compreender a estrutura, o conteúdo e a qualidade da base de dados antes de qualquer transformação ou análise estatística profunda.
#
# Sua importância reside na capacidade de identificar precocemente anomalias, inconsistências e padrões inesperados que poderiam comprometer a integridade dos resultados finais.

# %% [markdown]
# ### Resumo Estrutural e Tipagem
# O comando `df.info()` fornece uma visão técnica do dataframe, listando o nome das colunas, a quantidade de valores não nulos e o consumo de memória. Esta inspeção é o primeiro passo para validar se os tipos de dados atribuídos automaticamente pelo Pandas estão em conformidade com a natureza de cada variável.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1500000 non-null  int64
#  1   tpep_pickup_datetime   1500000 non-null  object
#  2   tpep_dropoff_datetime  1500000 non-null  object
#  3   passenger_count        1500000 non-null  int64
#  4   trip_distance          1500000 non-null  float64
#  5   pickup_longitude       1500000 non-null  float64
#  6   pickup_latitude        1500000 non-null  float64
#  7   RatecodeID             1500000 non-null  int64
#  8   store_and_fwd_flag     1500000 non-null  object
#  9   dropoff_longitude      1500000 non-null  float64
#  10  dropoff_latitude       1500000 non-null  float64
#  11  payment_type           1500000 non-null  int64
#  12  fare_amount            1500000 non-null  float64
#  13  extra                  1500000 non-null  float64
# ...

# %% [markdown]
# ### Análise de Valores Ausentes
# A identificação de valores nulos é fundamental para medir a integridade do dataset. O bloco de código abaixo calcula a soma absoluta e o percentual de registros faltantes para cada coluna. Esta métrica orienta a decisão sobre estratégias de limpeza, como a exclusão de registros incompletos ou a necessidade de imputação de dados em variáveis críticas para o negócio.

# %%
print("Valores nulos por coluna:")
nulos = df.isnull().sum()
nulos_percentual = (nulos / len(df) * 100).round(2)

resumo_nulos = pd.DataFrame({
    'Nulos': nulos,
    '% do total': nulos_percentual
})

print(resumo_nulos[resumo_nulos['Nulos'] > 0])
# Out:
# Valores nulos por coluna:
# Empty DataFrame
# Columns: [Nulos, % do total]
# Index: []

# %% [markdown]
# ### Estatística Descritiva de Variáveis Críticas
# A aplicação do método `.describe()` em colunas numéricas selecionadas permite observar a tendência central (média e mediana) e a dispersão dos dados. Esta análise é essencial para detectar a presença de outliers ou erros de registro.

# %%
colunas_criticas = ['passenger_count', 'trip_distance', 'fare_amount', 
                    'tip_amount', 'tolls_amount', 'total_amount',
                    'pickup_longitude', 'pickup_latitude',
                    'dropoff_longitude', 'dropoff_latitude']

df[colunas_criticas].describe().round(2)
# Out:
#        passenger_count  trip_distance  fare_amount  tip_amount  tolls_amount  \
# count       1500000.00     1500000.00   1500000.00  1500000.00    1500000.00
# mean              1.66           2.90        12.53        1.77          0.30
# std               1.32           6.05        11.72        2.73          1.59
# min               0.00           0.00      -376.00       -8.50         -5.54
# 25%               1.00           1.00         6.50        0.00          0.00
# 50%               1.00           1.70         9.00        1.32          0.00
# 75%               2.00           3.10        14.00        2.35          0.00
# max               9.00        5921.90      5000.00      850.00        554.00
#
#        total_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count    1500000.00        1500000.00       1500000.00         1500000.00
# mean          15.73            -72.85            40.13             -72.92
# ...

# %% [markdown]
# ### Análise Visual de Dispersão e Outliers
# Embora as tabelas estatísticas forneçam valores numéricos precisos, a representação visual por meio de boxplots permite uma percepção imediata da dispersão dos dados e da severidade de valores discrepantes (outliers). Essa técnica destaca visualmente corridas com distâncias ou valores que fogem drasticamente da normalidade operacional, facilitando a tomada de decisão sobre os limites que deverão ser impostos na fase de limpeza.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# boxplot para distância
sns.boxplot(x=df['trip_distance'], ax=axes[0], color='skyblue')
axes[0].set_title('Distribuição de Distância (Trip Distance)')

# boxplot para valor total
sns.boxplot(x=df['total_amount'], ax=axes[1], color='salmon')
axes[1].set_title('Distribuição de Valor Total (Total Amount)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matriz de Correlação de Variáveis Numéricas
# A matriz de correlação é uma ferramenta estatística que quantifica a força e a direção da relação linear entre pares de variáveis numéricas. No contexto do Data Profiling, esta matriz serve para confirmar relações lógicas esperadas do negócio e para identificar dependências inesperadas.

# %%
# seleção apenas das colunas numéricas para a correlação
colunas_numericas = ['passenger_count', 'trip_distance', 'fare_amount', 
                    'tip_amount', 'tolls_amount', 'total_amount']

corr = df[colunas_numericas].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Matriz de Correlação Inicial (Variáveis Numéricas)')
plt.show()

# %% [markdown]
# ### Identificação de Registros Duplicados
# A presença de linhas idênticas em um dataset pode indicar falhas nos processos de coleta, armazenamento ou na etapa de consolidação dos arquivos. A verificação de duplicatas é uma etapa de higiene fundamental para evitar a inflação artificial de métricas volumétricas e financeiras. Identificar e quantificar esses registros assegura que cada entrada no dataframe represente, de fato, um evento operacional único e fidedigno.

# %%
duplicados = df.duplicated().sum()
print(f"Total de registros duplicados: {duplicados}")
if duplicados > 0:
    print(f"Percentual de duplicatas: {(duplicados / len(df) * 100):.2f}%")
# Out:
# Total de registros duplicados: 0

# %% [markdown]
# ### Frequência de Variáveis Categóricas
# Para variáveis que representam categorias, utiliza-se o método `.value_counts()`. Esta operação enumera a frequência de cada categoria única, permitindo validar se os dados estão distribuídos conforme as normas da TLC e se existem códigos inválidos ou não documentados que devam ser tratados na fase de limpeza.

# %%
categoricas = ['payment_type', 'RatecodeID', 'store_and_fwd_flag', 'mes_origem']

for coluna in categoricas:
    print(f"\n{coluna}:", df[coluna].value_counts())
# Out:
# payment_type: payment_type
# 1    999173
# 2    493445
# 3      5474
# 4      1908
# Name: count, dtype: int64
#
# RatecodeID: RatecodeID
# 1     1462018
# 2       30353
# 5        4508
# 3        2456
# 4         629
# 99         25
# 6          11
# Name: count, dtype: int64
#
# store_and_fwd_flag: store_and_fwd_flag
# N    1491477
# Y       8523
# Name: count, dtype: int64
#
# mes_origem: mes_origem
# 01    500000
# 02    500000
# 03    500000
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Observações do Data Profiling
# Após a conclusão das rotinas de diagnóstico e perfilamento dos dados, consolidam-se as descobertas fundamentais sobre a base amostral do primeiro trimestre de 2016.
#
# ### Integridade e Consistência da Base
# O diagnóstico inicial revelou pontos de atenção imediatos quanto à estrutura das variáveis:
# - Identificou-se que as colunas temporais (`tpep_pickup_datetime` e `tpep_dropoff_datetime`) são carregadas originalmente como `object` (strings). Esta configuração impossibilita operações aritméticas de tempo, tornando a conversão para o formato `datetime64` um pré-requisito obrigatório para o cálculo da duração das viagens.
# - Os valores monetários e de distância foram corretamente identificados como tipos numéricos, permitindo o diagnóstico de dispersão e a identificação de anomalias estatísticas.
# - A verificação de registros duplicados retornou 0 ocorrências, assegurando que o processo de amostragem aleatória preservou a exclusividade de cada evento operacional.
#
# ### Contexto de Negócio
#
# **Regras de Tarifação (RatecodeID)**
# Para a correta interpretação do resultado do faturamento, é indispensável alinhar a análise às normas da TLC. O atributo `RatecodeID` determina a regra tarifária aplicada ao término de cada jornada:
# - 1- Standard Rate: Tarifa Padrão para os cinco distritos da cidade.
# - 2- JFK: Tarifa fixa (flat rate) para trajetos entre Manhattan e o Aeroporto JFK.
# - 3- Newark: Tarifa de taxímetro com sobretaxa para o Aeroporto de Newark.
# - 4- Nassau/Westchester: Tarifa metropolitana para condados vizinhos (tarifa dupla fora do limite da cidade).
# - 5- Negotiated Fare: Valor negociado diretamente entre motorista e passageiro.
# - 6- Group Ride: Tarifa para viagens partilhadas por múltiplos passageiros.
# - 99- Unknown: Registro de falha ou código desconhecido.
#
# Optou-se por manter as categorias de 1 a 6, pois elas representam diferentes modalidades operacionais legítimas que enriquecem a análise de rotas e faturamento. A categoria 99 será excluída, uma vez que não possui valor informativo e representa inconsistência no registro da tarifa.
#
# **Formas de Pagamento (payment_type):**
# Dentre os 4 métodos de pagamento identificados, serão considerados apenas os registros de categoria 1 (cartão de crédito) e 2 (dinheiro em espécie). As demais categorias serão descartadas, pois representam casos excepcionais, erros de sistema ou disputas judiciais que não refletem o comportamento padrão de consumo e faturamento do mercado.
#
# ### Estratégia de Seleção de Variáveis
# Para otimizar o processamento e reduzir a dimensionalidade do dataset, definiu-se o seguinte plano de manejo de colunas:
#
# **Variáveis a preservar:**
# - Temporais: `tpep_pickup_datetime`, `tpep_dropoff_datetime`.
# - Espaciais: `pickup_longitude`, `pickup_latitude`, `dropoff_longitude`, `dropoff_latitude`.
# - Operacionais: `passenger_count`, `trip_distance`, `RatecodeID`, `mes_origem`.
# - Financeiras: `fare_amount`, `tip_amount`, `tolls_amount`, `total_amount`, `payment_type`.
#
# **Variáveis a descartar:**
# - `VendorID`: Código técnico do fornecedor de hardware, sem impacto no comportamento da mobilidade.
# - `store_and_fwd_flag`: Registro logístico de transmissão de dados sem relevância analítica.
# - `extra`: Valores de sobretaxas já consolidados na métrica de valor total.
# - `mta_tax`: Taxa fixa de $0.50 (baixa variância).
# - `improvement_surcharge`: Taxa fixa de $0.30 (baixa variância).
#
# ### Diagnóstico de Anomalias (Outliers)
# O perfilamento identificou inconsistências operacionais que exigem intervenção:
# - Coordenadas localizadas fora da área metropolitana de Nova York ou em posições nulas (0, 0).
# - Impossibilidades físicas como corridas com duração de 0 minutos com cobrança ativa ou distâncias incompatíveis com o tempo de viagem registrado.
# - Inconsistências financeiras como registro de tarifas negativas e valores totais nulos em viagens com distância percorrida.

# %% [markdown]
# ## 8. Limpeza e Tratamento dos Dados
#
# Com base nos problemas identificados, esta etapa consiste na aplicação de filtros para remover registros que não representam a realidade operacional ou que possuem falhas de integridade. O objetivo é refinar o dataset para que as conclusões reflitam apenas viagens válidas no contexto. O processo é dividido em três fases:
# 1. Remoção de colunas técnicas e de baixa variância.
# 2. Conversão de tipos e cálculo de métricas derivadas.
# 3. Aplicação de limites físicos, financeiros e geográficos.

# %% [markdown]
# ### Redução de Dimensionalidade e Normalização
# Nesta fase removem-se as variáveis descartadas na análise de perfilamento e preparam-se as colunas temporais para o processamento.

# %%
# remoção de colunas
colunas_descartar = ['store_and_fwd_flag', 'VendorID', 'extra', 'mta_tax', 'improvement_surcharge']
df = df.drop(columns=colunas_descartar)

print(f"Dataset reduzido para {df.shape[1]} colunas.")
# Out:
# Dataset reduzido para 15 colunas.

# %%
# converter datas de texto para datetime
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
# calcular duração da viagem em minutos
df['duracao_min'] = (
    (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
)

# %% [markdown]
# ### Aplicação dos Filtros de Qualidade
# Abaixo aplica-se a lógica de filtragem consolidada nas observações anteriores.

# %%
# registrar tamanho original antes da limpeza

registros_originais = len(df)
print(f"Registros antes da limpeza: {registros_originais:,}")
# Out:
# Registros antes da limpeza: 1,500,000

# %%
# aplicação dos filtros

df_limpo = df[
    # passageiros: mínimo 1, máximo 9 (limite de vans/veículos especiais)
    (df['passenger_count'] >= 1) & (df['passenger_count'] <= 9) &

    # distância: mínimo 0.1 milhas, máximo 100 milhas
    (df['trip_distance'] >= 0.1) & (df['trip_distance'] <= 100) &

    # valor da corrida: mínimo $2.50, máximo $500
    (df['fare_amount'] >= 2.50) & (df['fare_amount'] <= 500) &

    # valor total: mínimo $2.50, máximo $500
    (df['total_amount'] >= 2.50) & (df['total_amount'] <= 500) &

    # gorjeta: sem valores negativos
    (df['tip_amount'] >= 0) &

    # pedágios: sem valores negativos
    (df['tolls_amount'] >= 0) &

    # duração: mínimo 1 minuto, máximo 180 minutos
    (df['duracao_min'] >= 1) & (df['duracao_min'] <= 180) &

    # payment type: apenas formas de pagamento válidas (1 ou 2)
    (df['payment_type'].isin([1, 2])) &

    # RatecodeID: apenas códigos válidos (1 a 6)
    (df['RatecodeID'] >= 1) & (df['RatecodeID'] <= 6) &

    # coordenadas: dentro dos limites aproximados de NYC e região metropolitana
    (df['pickup_longitude'] >= -74.3) & (df['pickup_longitude'] <= -73.7) &
    (df['pickup_latitude'] >= 40.4) & (df['pickup_latitude'] <= 40.9) &
    (df['dropoff_longitude'] >= -74.3) & (df['dropoff_longitude'] <= -73.7) &
    (df['dropoff_latitude'] >= 40.4) & (df['dropoff_latitude'] <= 40.9)
]

print(f"Registros originais: {registros_originais:,}")
print(f"Registros após limpeza: {len(df_limpo):,}")
print(f"Registros removidos: {registros_originais - len(df_limpo):,}")
print(f"Taxa de aproveitamento: {len(df_limpo)/registros_originais*100:.1f}%")
# Out:
# Registros originais: 1,500,000
# Registros após limpeza: 1,455,415
# Registros removidos: 44,585
# Taxa de aproveitamento: 97.0%

# %% [markdown]
# ### Análise de Impacto dos Filtros Individuais
# Para garantir o controle sobre o processo de limpeza, realiza-se um diagnóstico individual de cada critério de exclusão. Diferente da filtragem consolidada, aqui cada variável é isolada para quantificar quantos registros seriam removidos por cada regra de negócio.

# %%
# detalhamento individual dos filtros

filtros = {
    'passenger_count inválido': df[(df['passenger_count'] < 1) | (df['passenger_count'] > 6)],
    'trip_distance inválida': df[(df['trip_distance'] <= 0.1) | (df['trip_distance'] > 100)],
    'fare_amount inválido': df[(df['fare_amount'] < 2.50) | (df['fare_amount'] > 500)],
    'tip_amount negativo': df[df['tip_amount'] < 0],
    'tolls_amount negativo': df[df['tolls_amount'] < 0],
    'total_amount inválido': df[(df['total_amount'] < 2.50) | (df['total_amount'] > 500)],
    'duração inválida': df[(df['duracao_min'] < 1) | (df['duracao_min'] > 180)],
    'payment_type inválido': df[~df['payment_type'].isin([1, 2])],
    'RatecodeID inválido': df[~df['RatecodeID'].isin([1, 2, 3, 4, 5, 6])],
    'coordenadas fora de NYC': df[
        ~df['pickup_longitude'].between(-74.3, -73.7) |
        ~df['pickup_latitude'].between(40.4, 40.9) |
        ~df['dropoff_longitude'].between(-74.3, -73.7) |
        ~df['dropoff_latitude'].between(40.4, 40.9)
    ],
    'data fora do período': df[
        (df['tpep_pickup_datetime'].dt.year != 2016) |
        (~df['tpep_pickup_datetime'].dt.month.isin([1, 2, 3]))
    ],
}

print("Impacto individual de cada filtro:")
print(f"{'Filtro':<35} {'Registros removidos':>20} {'% do total':>12}")
print("-" * 70)
for nome, subset in filtros.items():
    qtd = len(subset)
    pct = qtd / registros_originais * 100
    print(f"{nome:<35} {qtd:>20,} {pct:>11.2f}%")
# Out:
# Impacto individual de cada filtro:
# Filtro                               Registros removidos   % do total
# ----------------------------------------------------------------------
# passenger_count inválido                              77        0.01%
# trip_distance inválida                            12,378        0.83%
# fare_amount inválido                               1,352        0.09%
# tip_amount negativo                                   17        0.00%
# tolls_amount negativo                                  1        0.00%
# total_amount inválido                              1,207        0.08%
# duração inválida                                  14,225        0.95%
# payment_type inválido                              7,382        0.49%
# RatecodeID inválido                                   25        0.00%
# coordenadas fora de NYC                           26,387        1.76%
# data fora do período                                   0        0.00%

# %% [markdown]
# ## 9. Exportação do Dataset Limpo
# Após a conclusão das etapas de limpeza e tratamento, o dataframe resultante é exportado para um arquivo de armazenamento permanente. Essa etapa é fundamental para o fluxo de trabalho por estabelecer um ponto de verificação, permitindo que as análises subsequentes sejam realizadas sem a necessidade de reprocessar os dados brutos.
#
# Para esta finalidade é utilizado o formato **Parquet**, devido às suas vantagens técnicas sobre formatos como o CSV:
# - Redução significativa do espaço ocupado em disco.
# - Otimização da performance de leitura para análise de grandes volumes de dados.
# - O formato mantém as tipagens das colunas intacta, eliminando a necessidade de novas conversões no futuro carregamento.

# %%
df_limpo.to_parquet('../data/nyc_taxi_limpo.parquet', index=False)

print(f"Registros: {len(df_limpo):,}")
print(f"Colunas: {df_limpo.shape[1]}")
# Out:
# Registros: 1,455,415
# Colunas: 16

# %% [markdown]
# Subsequentemente, procede-se ao carregamento deste arquivo e à configuração das bibliotecas de visualização, definindo padrões estéticos globais.

# %%
# carregar dataset limpo
df = pd.read_parquet('../data/nyc_taxi_limpo.parquet')

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

print(f"Dataset limpo carregado")

df.head()
# Out:
# Dataset limpo carregado
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2016-01-01 00:00:32   2016-01-01 00:13:20                5           3.60
# 1  2016-01-01 00:00:40   2016-01-01 00:14:03                1           4.30
# 2  2016-01-01 00:00:45   2016-01-01 00:09:17                6           1.85
# 3  2016-01-01 00:00:49   2016-01-01 00:09:01                1           1.22
# 4  2016-01-01 00:01:11   2016-01-01 00:08:06                1           1.50
#
#    pickup_longitude  pickup_latitude  RatecodeID  dropoff_longitude  \
# 0        -73.996948        40.720501           1         -73.958183
# 1        -73.966179        40.762222           1         -73.897758
# 2        -73.994202        40.726471           1         -74.014748
# 3        -73.982140        40.771687           1         -73.974457
# 4        -74.003487        40.741570           1         -74.002357
#
# ...

# %% [markdown]
# ## 10. Análise Exploratória de Dados
# A análise exploratória busca descobrir padrões, identificar anomalias e testar hipóteses formuladas durante o entendimento do problema. Para este projeto, a exploração será dividida em quatro pilares principais: temporal, financeiro, operacional e geoespacial.

# %% [markdown]
# ### 10.1 Análise de Séries Temporais
# Nesta etapa, investiga-se como o volume de corridas flutua ao longo do tempo. O foco está em identificar períodos de pico e sazonalidades.
#
# **Engenharia de atributos temporais:** Inicialmente são extraídos componentes específicos das colunas de data. Esta técnica, chamada de Feature Engineering, transforma um campo único de data em variáveis categoricas e numéricas que facilitam o agrupamento estatístico.

# %%
# extração de componentes temporais
df['hora'] = df['tpep_pickup_datetime'].dt.hour
df['dia_semana'] = df['tpep_pickup_datetime'].dt.day_name()
df['mes_nome'] = df['tpep_pickup_datetime'].dt.month_name()

# ordenação lógica dos dias da semana para visualização
dias_ordem = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['dia_semana'] = pd.Categorical(df['dia_semana'], categories=dias_ordem, ordered=True)

# ordenação lógica dos meses
meses_ordem = ['January', 'February', 'March']
df['mes_nome'] = pd.Categorical(df['mes_nome'], categories=meses_ordem, ordered=True)

print("Atributos temporais criados com sucesso.")
# Out:
# Atributos temporais criados com sucesso.

# %% [markdown]
# **Distribuição da demanda por hora do dia:** A análise horária identifica os períodos de pico (rush hours) e os momentos de ociosidade do sistema. Em uma metrópole como Nova York, espera-se uma distribuição bimodal, com picos associados ao início e ao fim do horário comercial.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df.groupby('hora').size().reset_index(name='contagem'), 
             x='hora', y='contagem', marker='o', color='darkblue')

plt.title('Distribuição de Corridas por Hora do Dia', fontsize=15)
plt.xlabel('Hora do Dia (24h)', fontsize=12)
plt.ylabel('Total de Corridas', fontsize=12)
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

corridas_hora = df.groupby('hora').size()
print(f"Hora de maior demanda : {corridas_hora.idxmax()}h — {corridas_hora.max():,} corridas")
print(f"Hora de menor demanda : {corridas_hora.idxmin()}h — {corridas_hora.min():,} corridas")
# Out:
# Hora de maior demanda : 18h — 92,409 corridas
# Hora de menor demanda : 5h — 14,461 corridas

# %% [markdown]
# **Variação da demanda por dia da semana:** Nesta etapa investiga-se se o volume de passageiros sofre alterações significativas entre os dias úteis e o final de semana. Esta análise auxilia na compreensão de como o comportamento de lazer e o fluxo de trabalho impactam a frota de taxis.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='dia_semana', hue='dia_semana', palette='magma', legend=False)

plt.title('Volume de Viagens por Dia da Semana', fontsize=15)
plt.xlabel('Dia da Semana', fontsize=12)
plt.ylabel('Total de Corridas', fontsize=12)
plt.show()

# %% [markdown]
# **Perfil da demanda horária por mês:** Enquanto os gráficos anteriores consolidam toda a amostra, esta visualização separa as curvas de densidade horária por mês, permitindo identificar se o comportamento dos passageiros se manteve estável ao longo do trimestre ou se houve variações sazonais.
#
# O gráfico de densidade (KDE) suaviza as contagens horárias em uma curva contínua, facilitando a comparação visual entre os meses sem que diferenças de volume absoluto distorçam a leitura. Se as três curvas se sobrepõem com fidelidade, isso confirma que o padrão de uso do taxi na cidade é robusto e independente do mês dentro do trimestre.

# %%
plt.figure(figsize=(12, 6))

# gráfico de densidade sobreposto para comparar os meses
sns.kdeplot(
    data=df, 
    x='hora', 
    hue='mes_nome', 
    common_norm=False, 
    palette='bright', 
    fill=True, 
    alpha=0.1
)

plt.title('Comparativo do Perfil de Demanda Horária por Mês', fontsize=15)
plt.xlabel('Hora do Dia', fontsize=12)
plt.ylabel('Densidade de Corridas', fontsize=12)
plt.xticks(range(0, 24))
plt.show()

# %% [markdown]
# **Variação dos horários de pico por dia da semana:** Enquanto os dias úteis costumam apresentar picos claros, os finais de semana tendem a apresentar uma curva de demanda crescente que se estende até a madrugada. Para visualizar essa dinâmica, utiliza-se um mapa de calor que permite identificar visualmente a densidade de corridas cruzando a hora do dia com cada dia da semana.

# %%
# agrupamento dos dados por dia e hora
df_heat = df.groupby(['dia_semana', 'hora'], observed=True).size().unstack(fill_value=0)

plt.figure(figsize=(16, 8))
sns.heatmap(df_heat, cmap="YlGnBu", annot=False, cbar_kws={'label': 'Total de Corridas'})

plt.title('Mapa de Calor: Intensidade de Demanda por Dia e Hora', fontsize=16)
plt.xlabel('Hora do Dia', fontsize=12)
plt.ylabel('Dia da Semana', fontsize=12)
plt.xticks(range(0, 24))
plt.show()

# %% [markdown]
# **Perfil da demanda em dias úteis vs. finais de semana:** O gráfico permite comparar isoladamente a curva de demanda horária de cada dia da semana. Esta visualização confirma se o comportamento bimodal dos dias úteis é consistente entre segunda e quinta, e se o padrão noturno de sexta e sábado é estrutural ou pontual.

# %%
# plot facetado para visualização isolada das curvas de demanda
g = sns.relplot(
    data=df.groupby(['dia_semana', 'hora'], observed=True).size().reset_index(name='contagem'),
    x="hora", y="contagem", col="dia_semana", col_wrap=4,
    kind="line", height=3, aspect=1.5, marker='o', facet_kws={'sharey': False}
)

g.set_axis_labels("Hora do Dia", "Total de Corridas")
g.set_titles("{col_name}")
g.tight_layout()

plt.show()

# %% [markdown]
# ### Conclusões da Análise Temporal
# A análise do primeiro trimestre demonstra que a demanda por taxis em Nova York é altamente cíclica e previsível, sendo ditada pelo horário comercial e pela vida noturna da cidade.
#
# De segunda a quinta-feira, o perfil da demanda é bi-modal. Observa-se um crescimento acelerado da quantidade de corridas a partir das 06h, atingindo o primeiro ápice entre 08h e 09h, coincidindo com o início da jornada de trabalho. O volume máximo diário ocorre entre 18h e 19h, representando o fluxo de saída dos escritórios e o deslocamento para atividades noturnas.
#
# O volume de viagens aumenta progressivamente ao longo da semana, culminando na sexta-feira, que registra o maior volume total de corridas.
#
# No sábado e domingo, o pico matinal desaparece. O mapa de calor revela uma densidade de chamadas nas madrugadas de sábado e domingo (entre 00h e 03h), refletindo o impacto do setor de entretenimento e lazer.
#
# Apesar de janeiro, fevereiro e março apresentarem condições climáticas distintas, o eprfil horário de demanda permanece praticamente idêntico em todos os meses. Isso indica que o hábito de utilização do serviço de taxi é resiliente a variações sazonais leves dentro do mesmo trimestre, mantendo o comportamento da cidade constante.

# %% [markdown]
# ### 10.2 Análise Financeira e de Rentabilidade
# Esta subseção explora a estrutura de custos e a geração de receita, utilizando métricas que relacionam o esforço operacional ao retorno financeiro.

# %% [markdown]
# **Correlação entre distância e valor da tarifa:** A base do faturamento de um taxi reside na relação direta entre a distância percorrida e a tarifa calculada. Através de um gráfico de dispersão com linha de regressão, é possível validar se a cobrança segue uma tendência linear positiva forte. Desvios significativos geralmente indicam a aplicação de tarifas fixas, como o código 2 para o aeroporto JFK, ou situações de tráfego intenso onde o fator tempo prevalece sobre a distância.

# %%
plt.figure(figsize=(12, 7))

# amostragem reduzida para otimizar a visualização e evitar overplotting
df_sample = df.sample(n=100000, random_state=42)

sns.regplot(data=df_sample, x='trip_distance', y='fare_amount', 
            scatter_kws={'alpha':0.2, 'color':'teal'}, 
            line_kws={'color':'red', 'label':'Tendência Linear'})

plt.title('Correlação: Distância da Viagem vs. Valor da Tarifa', fontsize=15)
plt.xlabel('Distância (Milhas)', fontsize=12)
plt.ylabel('Valor da Tarifa (USD)', fontsize=12)
plt.xlim(0, 40)
plt.ylim(0, 150)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# **Comportamento e distribuição de gorjetas:** As gorjetas representam uma parte importante da renda dos motoristas, porém sua análise é restrita às transações eletrônicas, visto que o sistema não registra gratificações em espécie. Para normalizar a análise independentemente da distância da viagem, utiliza-se o cálculo do percentual de gorjeta: `pct_gorjeta = (tip_amount / fare_amount) x 100`.

# %%
# filtragem de pagamentos em cartão
df_tips = df[df['payment_type'] == 1].copy()
df_tips['pct_gorjeta'] = (df_tips['tip_amount'] / df_tips['fare_amount']) * 100

# filtro de visualização para focar na distribuição real (removendo anomalias extremas)
df_tips_viz = df_tips[df_tips['pct_gorjeta'] <= 40]

plt.figure(figsize=(12, 6))
sns.histplot(df_tips_viz['pct_gorjeta'], bins=40, kde=True, color='gold')

mediana_tip = df_tips_viz['pct_gorjeta'].median()
plt.axvline(mediana_tip, color='red', linestyle='--', label=f'Mediana: {mediana_tip:.1f}%')

plt.title('Distribuição do Percentual de Gorjeta (Transações via Cartão)', fontsize=15)
plt.xlabel('Porcentagem da Gorjeta (%)', fontsize=12)
plt.ylabel('Frequência de Corridas', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# **Relação entre gorjeta e distância da viagem:** Para entender se o passageiro é mais generoso em viagens curtas ou longas, foi analisado o percentual de gorjeta em relação à distância. A distância foi agrupada em faixas de 2 milhas para suavizar a visualização e identificar tendências.

# %%
# criando faixas de distância
df_tips['distancia_bin'] = pd.cut(df_tips['trip_distance'], bins=range(0, 32, 2))

# calculando a média de gorjeta por faixa de distância
tip_distancia = df_tips.groupby('distancia_bin', observed=True)['pct_gorjeta'].mean().reset_index()

plt.figure(figsize=(14, 6))
sns.lineplot(data=tip_distancia, x=tip_distancia.index, y='pct_gorjeta', marker='o', color='darkgreen')

plt.title('Percentual Médio de Gorjeta por Distância da Viagem', fontsize=15)
plt.xlabel('Faixa de Distância (Milhas)', fontsize=12)
plt.ylabel('Média de Gorjeta (%)', fontsize=12)
plt.xticks(range(len(tip_distancia)), tip_distancia['distancia_bin'], rotation=45)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **Gorjeta por quantidade de passageiros:** Esta análise verifica se a contagem de passageiros na corrida influencia o comportamento de gratificação.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_tips[df_tips['passenger_count'] <= 6], 
            x='passenger_count', y='pct_gorjeta', 
            hue='passenger_count', palette='magma', legend=False)

plt.title('Média de Gorjeta por Quantidade de Passageiros', fontsize=15)
plt.xlabel('Número de Passageiros', fontsize=12)
plt.ylabel('Média de Gorjeta (%)', fontsize=12)
plt.show()

# %% [markdown]
# **Gorjeta por hora do dia:** Cruzando o comportamento de gratificação com o horário da corrida, é possível identificar se passageiros em determinados períodos do dia são sistematicamente mais generosos. Corridas na madrugada, por exemplo, tendem a envolver deslocamentos para lazer, contexto diferente do rush da manhã, onde o passageiro está sob pressão de tempo. Esta análise complementa a visão temporal iniciada anteriormente, adicionando uma dimensão financeira ao perfil horário.

# %%
gorjeta_hora = df[df['payment_type'] == 1].copy()
gorjeta_hora['pct_gorjeta'] = (gorjeta_hora['tip_amount'] / gorjeta_hora['fare_amount']) * 100
gorjeta_hora = gorjeta_hora[gorjeta_hora['pct_gorjeta'] <= 40]

plt.figure(figsize=(12, 6))
sns.lineplot(
    data=gorjeta_hora.groupby('hora')['pct_gorjeta'].mean().reset_index(),
    x='hora', y='pct_gorjeta', marker='o', color='goldenrod'
)
plt.title('Percentual Médio de Gorjeta por Hora do Dia', fontsize=15)
plt.xlabel('Hora do Dia', fontsize=12)
plt.ylabel('Média de Gorjeta (%)', fontsize=12)
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

hora_max = gorjeta_hora.groupby('hora')['pct_gorjeta'].mean()
print(f"Hora com maior gorjeta média : {hora_max.idxmax()}h — {hora_max.max():.1f}%")
print(f"Hora com menor gorjeta média : {hora_max.idxmin()}h — {hora_max.min():.1f}%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 7
#       3 gorjeta_hora = gorjeta_hora[gorjeta_hora['pct_gorjeta'] <= 40]
#       5 plt.figure(figsize=(12, 6))
#       6 sns.lineplot(
# ----> 7     data=gorjeta_hora.groupby('hora')['pct_gorjeta'].mean().reset_index(),
#       8     x='hora', y='pct_gorjeta', marker='o', color='goldenrod'
#       9 )
#      10 plt.title('Percentual Médio de Gorjeta por Hora do Dia', fontsize=15)
#      11 plt.xlabel('Hora do Dia', fontsize=12)
#
# File ~/Documents/nyc-taxi-analysis/venv/lib/python3.10/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
# ...

# %% [markdown]
# **Ticket médio por código de tarifa:** Comparação do valor médio total das corridas entre as diferentes regras de tarifação mantidas no dataset. O objetivo desta análise é identificar quais modalidades de viagem oferecem o maior ticket médio, auxiliando na compreensão da lucratividade por categoria operacional.

# %%
# agrupamento sem ordenação arbitrária
ticket_medio = df.groupby('RatecodeID')['total_amount'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=ticket_medio, x='RatecodeID', y='total_amount', 
hue='RatecodeID', palette='magma', legend=False)

plt.title('Ticket Médio (Total Amount) por Código de Tarifa', fontsize=15)
plt.xlabel('Código de Tarifa (RatecodeID)', fontsize=12)
plt.ylabel('Valor Médio (USD)', fontsize=12)

# inclusão dos rótulos sobre as barras
for i, row in ticket_medio.iterrows():
    plt.text(i, row['total_amount'] + 1, f'${row["total_amount"]:.2f}', 
             ha='center', fontweight='bold', fontsize=11)

plt.ylim(0, ticket_medio['total_amount'].max() + 15)
plt.show()

# %% [markdown]
# **Faturamento total por meio de pagamento:** A distribuição da receita bruta entre dinheiro e cartão revela a preferência dos usuários e o volume financeiro transacionado por cada via. Esta visão é complementar à análise de gorjetas, pois contextualiza a representatividade de cada método no faturamento global.

# %%
faturamento_pgto = df.groupby('payment_type')['total_amount'].sum().reset_index()
faturamento_pgto['payment_type'] = faturamento_pgto['payment_type'].map({1: 'Cartão', 2: 'Dinheiro'})

plt.figure(figsize=(8, 8))
plt.pie(faturamento_pgto['total_amount'], labels=faturamento_pgto['payment_type'], 
        autopct='%1.1f%%', startangle=140, colors=['#5DADE2', '#58D68D'], explode=(0.05, 0))

plt.title('Distribuição do Faturamento Bruto por Meio de Pagamento', fontsize=15)
plt.show()

# %% [markdown]
# ### Conclusões da Análise Financeira
# A estrutura de faturamento revela onde reside o lucro real para os operadores e como a cultura de gratificação se comporta.
#
# O ticket médio da tarifa padrão (`Rate 1`) é de $14.44, enquanto viagens para o aeroporto Newark (`Rate 3`) atingem $92.88 e JFK (`Rate 2`) ficam em $65.22. Isso demonstra que, embora o volume esteja na cidade, a margem e a eficiência de tempo/lucro estão nas rotas intermunicipais e aeroportuárias.
#
# O meio de pagamento eletrônico já domina o mercado, representando 73,1% do faturamento total das corridas analisadas.
#
# A gratificação em Nova York é culturalmente padronizada, com uma mediana de 22%. Notavelmente, o percentual de gorjeta é maior em viagens muito curtas (até 2 milhas), onde ultrapassa os 23%, e tende a se estabilizar em torno de 19-20% em trajetos mais longos. A quantidade de passageiros no veículo não influencia o percentual de gorjeta.

# %% [markdown]
# ### 10.3 Análise Geoespacial
# Através das coordenadas de latitude e longitude, é possível transformar milhares de registros em mapas de calor que revelam as zonas de maior concentração de passageiros. Esta análise foca-se na identificação de polos geradores de viagens, como terminais de transporte, centros financeiros (Midtown/Wall Street) e áreas de lazer.

# %% [markdown]
# **Visualização geral de embarques:** Dada a elevada densidade de pontos, utiliza-se uma amostra estatística e o parâmetro `alpha` para evitar a sobreposição total dos dados (overplotting), permitindo ver a silhueta da ilha de Manhattan e dos distritos vizinhos.

# %%
df_geo_sample = df.sample(n=20_000, random_state=42)

fig = px.scatter_map(
    df_geo_sample,
    lat='pickup_latitude',
    lon='pickup_longitude',
    color='total_amount',
    color_continuous_scale='Inferno',
    range_color=[0, 40],
    zoom=10,
    center=dict(lat=40.75, lon=-73.98),
    height=600,
    title='Distribuição Geoespacial de Embarques — Q1 2016',
    opacity=0.3,
    map_style='carto-darkmatter'
)
fig.update_traces(marker=dict(size=3))
fig.show()

# %% [markdown]
# **Visualização geral dos desembarques:** Esta visualização utiliza a mesma amostragem e bounding box definido anteriormente, permitindo uma comparação direta com o mapa de embarques.

# %%
fig = px.scatter_map(
    df_geo_sample,
    lat='dropoff_latitude',
    lon='dropoff_longitude',
    color='total_amount',
    color_continuous_scale='Inferno',
    range_color=[0, 40],
    zoom=10,
    center=dict(lat=40.75, lon=-73.98),
    height=600,
    title='Distribuição Geoespacial de Desembarques — Q1 2016',
    opacity=0.3,
    map_style='carto-darkmatter'
)
fig.update_traces(marker=dict(size=3))
fig.show()

# %% [markdown]
# **Comparativo entre origem e destino:** A comparação entre o início e o fim das corridas permite identificar se há um deslocamento da frota para áreas específicas. A aplicação do filtro geográfico uniforme em ambos os mapas garante a comparabilidade dos dados.

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(
    rows=1, cols=2,
    specs=[[{'type': 'map'}, {'type': 'map'}]],
    subplot_titles=('Embarques (Pickups)', 'Desembarques (Dropoffs)')
)

# mapa de embarques
fig.add_trace(
    go.Scattermap(
        lat=df_geo_sample['pickup_latitude'],
        lon=df_geo_sample['pickup_longitude'],
        mode='markers',
        marker=dict(size=3, color='#4A90D9', opacity=0.5),
        name='Embarque'
    ),
    row=1, col=1
)

# mapa de desembarques
fig.add_trace(
    go.Scattermap(
        lat=df_geo_sample['dropoff_latitude'],
        lon=df_geo_sample['dropoff_longitude'],
        mode='markers',
        marker=dict(size=3, color='#E74C3C', opacity=0.5),
        name='Desembarque'
    ),
    row=1, col=2
)

fig.update_layout(
    map1=dict(
        style='carto-darkmatter',
        center=dict(lat=40.75, lon=-73.98),
        zoom=10
    ),
    map2=dict(
        style='carto-darkmatter',
        center=dict(lat=40.75, lon=-73.98),
        zoom=10
    ),
    title=dict(
        text='Comparativo Geoespacial: Embarques vs Desembarques — Q1 2016',
        font=dict(size=16)
    ),
    height=650,
    showlegend=True
)

fig.show()

# %% [markdown]
# **Densidade de embarques:** O mapa de densidade agrega os pontos de embarque por grade geográfica e aplica um gradiente de cor para revelar as zonas de maior concentração. Esta visualização elimina o ruído individual de cada corrida e destaca os bairros que realmente sustentam o volume operacional do sistema.

# %%
# mapa de densidade por valor médio de corrida por região
df['regiao_lat'] = df['pickup_latitude'].round(2)
df['regiao_lon'] = df['pickup_longitude'].round(2)

densidade = df.groupby(['regiao_lat','regiao_lon']).agg(
    corridas=('total_amount','count'),
    receita_media=('total_amount','mean')
).reset_index()

fig = px.density_map(
    densidade,
    lat='regiao_lat',
    lon='regiao_lon',
    z='corridas',
    radius=15,
    zoom=10,
    center=dict(lat=40.75, lon=-73.98),
    height=650,
    color_continuous_scale='Inferno',
    title='Mapa de Densidade de Embarques — Concentração por Região',
    map_style='carto-darkmatter'
)
fig.show()

# %% [markdown]
# ### Conclusões da Análise Geoespacial
# A ilha de Manhattan atua como o motor central do sistema de taxis. A densidade de embarques é crítica em Midtown e no Financial District, estendendo-se de forma massiva até as bordas do Central Park. Esta concentração justifica a predominância do `Ratecode 1` observado na análise financeira, caracterizando corridas curtas e frequentes dentro da malha urbana mais densa do mundo.
#
# Fora da ilha principal, observam-se dois clusters isolados de altíssima densidade:
# - Aeroporto JFK (Sudeste): Um ponto focal de embarques e desembarques que gera os maiores tickets médios do dataset (~ $65.00).
# - Aeroporto LaGuardia (Queens): Um hub constante de fluxo que sustenta a operação fora do eixo central de Manhattan.
#
# A visualização em escala logarítmica confirma que esses pontos, embora geograficamente pequenos, possuem um volume de transações comparável aos grandes centros comerciais de Manhattan.
#
# Ao comparar os mapas de origem e destino, nota-se uma sutil mas importante diferença na distribuição. Os embarques são mais agrupados em áreas comerciais, hotéis e terminais de transporte, enquanto desembarques apresentam uma dispersão maior para áreas residenciais, como Upper Manhattan, Brooklyn e partes do Queens. Esta assimetria sugere que o passageiro utiliza o taxi para retornar a bairros mais afastados após compromissos no centro, exigindo que o motorista realize trajetos "vazios" para se reposicionar nos hubs de embarque.
#
# A precisão do bounding box e a limpeza dos dados são validadas pela nitidez dos espaços vazios. O Central Park aparece como um retângulo perfeitamente definido sem pontos, assim como os rios Hudson e East River. Isso comprova que os filtros de limpeza removeram com sucesso os erros de GPS que posicionariam veículos em locais impossíveis.

# %% [markdown]
# ### 10.4 Análise de Eficiência Operacional
# Esta etapa foca na "física" do transporte urbano. É calculada a velocidade média para mapear o congestionamento da cidade e a eficiência financeira, transformando as métricas de tempo e distância em indicadores de performance.

# %% [markdown]
# **Cálculo da velocidade média e produtividade:** Corridas com velocidade muito baixa indicam retenções severas, enquanto velocidades mais altas sugerem trajetos fluidos ou uso de vias expressas. A fórmula utilizada é `V média = (trip_distance / duracao_min) x 60`.

# %%
# cálculo da velocidade média (MPH)
df['velocidade_mph'] = (df['trip_distance'] / df['duracao_min']) * 60

# cálculo da rentabilidade por minuto (USD/min)
df['faturamento_por_minuto'] = df['total_amount'] / df['duracao_min']

# filtragem de segurança para remover outliers de velocidade (erros de GPS ou tempo)
df_operacional = df[(df['velocidade_mph'] > 1) & (df['velocidade_mph'] < 80)].copy()

print("Métricas operacionais calculadas.")
# Out:
# Métricas operacionais calculadas.

# %% [markdown]
# **Velocidade média por hora do dia:** Este gráfico revela o "engarrafamento" da cidade. Ao cruzar essa curva com a de volume de corridas, podemos observar se o aumento da demanda coincide com a queda da velocidade, caracterizando o horário de rush.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_operacional.groupby('hora')['velocidade_mph'].mean().reset_index(), 
             x='hora', y='velocidade_mph', marker='o', color='darkorange')

plt.title('Velocidade Média da Frota por Hora do Dia', fontsize=15)
plt.xlabel('Hora do Dia', fontsize=12)
plt.ylabel('Velocidade Média (MPH)', fontsize=12)
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# **Produtividade financeira:** É analisado quanto o motorista fatura por minuto de trabalho em diferentes horários. Essa métrica ajuda a identificar se compensa mais estar na rua durante o pico (muitas corridas lentas) ou na madrugada (poucas corridas rápidas).

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_operacional.groupby('hora')['faturamento_por_minuto'].mean().reset_index(), 
            x='hora', y='faturamento_por_minuto', 
            hue='hora', palette='magma', legend=False)

plt.title('Faturamento Médio por Minuto de Viagem', fontsize=15)
plt.xlabel('Hora do Dia', fontsize=12)
plt.ylabel('USD por Minuto', fontsize=12)
plt.show()

# %% [markdown]
# **Eficiência financeira por código de tarifa:** Verificação se o faturamento por minuto de trabalho compensa o gasto em viagens de longa distância para os aeroportos.

# %%
# agrupando a eficiência financeira média por Código de Tarifa
eficiencia_tarifa = df_operacional.groupby('RatecodeID')['faturamento_por_minuto'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=eficiencia_tarifa, x='RatecodeID', y='faturamento_por_minuto', 
hue='RatecodeID', palette='magma', legend=False)

plt.title('Eficiência Financeira (USD/Min) por Código de Tarifa', fontsize=15)
plt.xlabel('Código de Tarifa (RatecodeID)', fontsize=12)
plt.ylabel('Faturamento Médio por Minuto (USD)', fontsize=12)

# adicionando os valores exatos para comparação
for i, row in eficiencia_tarifa.iterrows():
    plt.text(i, row['faturamento_por_minuto'] + 0.05, f'${row["faturamento_por_minuto"]:.2f}/min', 
             ha='center', fontweight='bold')

plt.show()

# %% [markdown]
# **Faturamento por minuto isolado por tarifa:** O gráfico anterior mostra a média geral por RatecodeID, mas não revela a distribuição individual das corridas. Esta análise usa um boxplot para mostrar a dispersão do faturamento por minuto dentro de cada categoria tarifária — revelando se a vantagem financeira das rotas aeroportuárias é consistente ou concentrada em poucos outliers.

# %%
# mapeamento dos códigos para nomes legíveis
rate_labels = {
    1: 'Padrão',
    2: 'JFK',
    3: 'Newark',
    4: 'Nassau/\nWestchester',
    5: 'Negociada',
    6: 'Grupo'
}

df_operacional['tarifa_label'] = df_operacional['RatecodeID'].map(rate_labels)

# limitar outliers extremos para visualização
df_box = df_operacional[df_operacional['faturamento_por_minuto'] <= 5]

fig, ax = plt.subplots(figsize=(13, 6))
sns.boxplot(
    data=df_box,
    x='tarifa_label',
    y='faturamento_por_minuto',
    hue='tarifa_label',
    palette='magma',
    legend=False,
    order=[rate_labels[i] for i in sorted(rate_labels.keys()) if rate_labels[i] in df_box['tarifa_label'].values],
    ax=ax
)

ax.set_title('Distribuição do Faturamento por Minuto por Tipo de Tarifa', fontsize=15)
ax.set_xlabel('Tipo de Tarifa', fontsize=12)
ax.set_ylabel('USD por Minuto', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# resumo numérico
print("Faturamento médio por minuto por tarifa:")
resumo = df_operacional.groupby('tarifa_label')['faturamento_por_minuto'].agg(['mean','median','std']).round(3)
resumo.columns = ['Média', 'Mediana', 'Desvio Padrão']
print(resumo.sort_values('Média', ascending=False))
# Out:
# Faturamento médio por minuto por tarifa:
#                       Média  Mediana  Desvio Padrão
# tarifa_label
# Negociada             5.710    3.243         15.819
# Newark                2.771    2.670          1.147
# Nassau/\nWestchester  2.058    1.825          2.669
# JFK                   1.793    1.562          2.099
# Padrão                1.281    1.173          0.493
# Grupo                 0.298    0.298          0.144

# %% [markdown]
# ### Conclusões da Análise Operacional
# A análise cruza a demanda absoluta com a velocidade média da frota, revelando uma correlação inversamente proporcional. O pico de demanda ocorre entre as 18h e 19h, superando 90.000 corridas por hora. No entanto, este é o momento de menor eficiência, com a velocidade média caindo para 10,3 MPH devido ao congestionamento. Embora as 05h registrem o menor volume de chamadas, é o horário de maior performance operacional, onde a velocidade média dobra para 20 MPH.
#
# Ao transformar a receita em uma métrica de tempo (dólares por minuto), foi identificado onde o esforço do motorista é melhor remunerado. O faturamento médio por minuto atinge seu ápice às 05h, chegando a $1.75/min. A fluidez das vias permite que mais milhas sejam percorridas e cobradas em menos tempo. Durante o horário comercial (08h às 18h), a rentabilidade permanece estagnada em patamares mais baixos, flutuando entre $1.15 e $1.25/min. O custo de oportunidade de ficar preso no trânsito urbano penaliza a receita líquida por hora trabalhada.
#
# A validação técnica dos códigos de tarifa prova que trajetos específicos oferecem retornos maiores sobre o tempo investido. O Ratecode 5 (negociado) é o líder absoluto de eficiência, gerando $5.71/min. Viagens para o aeroporto de Newark (Ratecode 3) rendem $2.77/min, enquanto o JFK (Ratecode 2) rende $1.79/min. A tarifa padrão (Ratecode 1) rende apenas $1.28/min, sendo a segunda categoria menos eficiente do sistema, perdendo apenas para a tarifa de corridas em grupo, com rendimento operacional de $0.30/min e menor ticket médio do dataset.
#
# A tarifa 6 refere-se ao "Group Ride", modalidade utilizada para viagens compartilhadas onde passageiros eram coletados em pontos específicos e levados a destinos comuns ou zonas pré-determinadas por um valor fixo reduzido por pessoa. Os dados mostram que, apesar de ser uma tentativa de otimização de passageiros, essa tarifa resulta em uma rentabilidade extremamente baixa para o motorista por minuto de ocupação do veículo.

# %% [markdown]
# ## 11. Conclusão Geral
# **Demanda:** A demanda é altamente previsível e cíclica. Dias úteis apresentam perfil bimodal (picos às 09h e 18h-19h), enquanto sexta e sábado concentram o maior volume absoluto de corridas, com demanda noturna estendida até a madrugada.
#
# **Financeiro:** O ticket médio das corridas padrão é de ~ $14.00, mas corridas para aeroportos geram ticket 4-6x maior. Gorjetas são exclusivamente registradas em pagamentos com cartão.
#
# **Geoespacial:** Manhattan concentra mais de 80% dos embarques, com densidade crítica em Midtown e no Financial District. Os aeroportos JFK e LaGuardia aparecem como polos secundários de alta receita unitária.
#
# **Operacional:** Existe uma correlação inversa entre volume e eficiência. O horário de pico (18h-19h) é o de menor velocidade média (~ 10 MPH) e não necessariamente o de maior faturamento por minuto. A madrugada apresenta corridas mais rápidas e financeiramente mais eficientes para o motorista.
#
# **Limitações da análise:** Os dados representam 4,3% do volume total do trimestre via amostragem aleatória estratificada. Gorjetas em dinheiro não são registradas pelo sistema, o que subestima o rendimento real dos motoristas em pagamentos em espécie.
