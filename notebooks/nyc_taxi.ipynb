# %% [markdown]
# # NYC Yellow Taxi Trips
#
# ## Sobre o Dataset
#
# **Fonte dos dados:** Kaggle - NYC Yellow Taxi Trip Data (elemento) - Version 2
# **Cobertura:** 1º trimestre de 2016
# **Volume original:** ~ 5,5GB
# **Formato:** CSV com múltiplos arquivos mensais separados
#
# Cada linha representa uma corrida individual de taxi, contendo informações de data e hora de embarque e desembarque, localização de origem e de destino, número de passageiros, distância percorrida, tarifas, gorjetas e forma de pagamento.
#
# ## Amostragem
#
# Cada arquivo CSV possui aproximadamente 1,8 GB, o volume de dados é inviável para carregamento integral em um ambiente com 8GB de RAM.
#
# O dataset completo do 1º trimestre de 2016 contém 34.499.859 corridas:
# - Janeiro: 10.906.858 corridas
# - Fevereiro: 11.382.049 corridas
# - Março: 12.210.952 corridas
#
# Por isso, foi adotada uma amostragem aleatória por arquivo mensal, no qual o total de linhas foi contabilizado e 500.000 registros foram selecionados aleatoriamente via numpy, totalizando 1,5 milhão de registros na amostra de trabalho.
#
# Essa abordagem é estatisticamente mais robusta do que simplesmente carregar as primeiras N linhas, pois garante representatividade ao longo de todo o período mensal, evitando viés.
#
# ## Perguntas respondidas
# - Qual é a evolução do volume de corridas e faturamento ao longo do trimestre?
# - Quais são os horários e dias de maior demanda?
# - Quais regiões geram mais receita?
# - O que influencia o valor da gorjeta?
# - Quais padrões indicam corridas atípicas ou suspeitas?
#
# ## Tecnologias utilizadas
# - Python 3
# - Pandas
# - NumPy
# - Matplotlib
# - Plotly
# - VS Code + Jupyter Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import os

sns.set_theme(style="darkgrid")
plt.rcParams['figure.figsize'] = (13, 5)
plt.rcParams['font.size'] = 12

# %%
import subprocess

AMOSTRA_POR_ARQUIVO = 500_000

pasta = '../data/'
arquivos_csv = sorted([
    f for f in os.listdir(pasta) 
    if f.startswith('yellow_tripdata_2016') 
    and f.endswith('.csv')
])

dfs = []
for arquivo in arquivos_csv:

    # contar total de linhas no arquivo
    resultado = subprocess.run(
        ['wc', '-l', pasta + arquivo], 
        capture_output=True, text=True
    )
    total_linhas = int(resultado.stdout.strip().split()[0]) - 1  # Subtrair 1 para o cabeçalho
    print(f"{arquivo} — {total_linhas:,} linhas")

    # calcular quais linhas pular para amostra aleatória
    linhas_pular = sorted(
        np.random.choice(
            range(1, total_linhas + 1),  # Linhas começam em 1 por causa do cabeçalho
            size=total_linhas - AMOSTRA_POR_ARQUIVO,
            replace=False
        )
    )
    
    # carregar apenas as linhas selecionadas
    df_temp = pd.read_csv(
        pasta + arquivo, 
        skiprows=linhas_pular,
        low_memory=False
    )
    df_temp['mes_origem'] = arquivo.split('-')[1].replace('.csv', '')
    dfs.append(df_temp)
    print(f"Amostra carregada - {len(df_temp):,} linhas\n")
# Out:
# yellow_tripdata_2016-01.csv — 10,906,858 linhas
# Amostra carregada - 500,000 linhas
#
# yellow_tripdata_2016-02.csv — 11,382,049 linhas
# Amostra carregada - 500,000 linhas
#
# yellow_tripdata_2016-03.csv — 12,210,952 linhas
# Amostra carregada - 500,000 linhas

# %% [markdown]
# ## Carregamento dos dados
#
# Nesta etapa são carregados os 3 arquivos CSV mensais, unificados em um único DataFrame, e é feito o reconhecimento inicial do dataset.

# %%
df = pd.concat(dfs, ignore_index=True)
print(f"DataFrame final: {len(df):,} linhas")

df.head()
# Out:
# DataFrame final: 1,500,000 linhas
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:06   2016-01-01 00:07:14                1
# 1         2  2016-01-01 00:00:32   2016-01-01 00:13:20                5
# 2         2  2016-01-01 00:01:19   2016-01-01 00:03:12                2
# 3         1  2016-01-01 00:01:20   2016-01-01 00:07:24                2
# 4         2  2016-01-01 00:01:23   2016-01-01 00:09:22                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.38        -73.994843        40.718498           1
# 1           3.60        -73.996948        40.720501           1
# 2           0.37        -73.997696        40.737659           1
# 3           1.00        -73.967552        40.756859           1
# 4           1.11        -73.998611        40.738171           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.989807         40.734230             1
# 1                  N         -73.958183         40.721790             1
# 2                  N         -73.991241         40.734982             2
# 3                  N         -73.978310         40.748611             1
# 4                  N         -73.994591         40.750549             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          7.0    0.5      0.5        1.66           0.0
# 1         13.5    0.5      0.5        2.96           0.0
# 2          3.5    0.5      0.5        0.00           0.0
# 3          6.0    0.5      0.5        1.45           0.0
# 4          7.0    0.5      0.5        1.66           0.0
#
#    improvement_surcharge  total_amount mes_origem
# 0                    0.3          9.96         01
# 1                    0.3         17.76         01
# 2                    0.3          4.80         01
# 3                    0.3          8.75         01
# 4                    0.3          9.96         01

# %% [markdown]
# ## Data Profiling
#
# **1. Estrutura e tipos de dados (df.info())**
# Revela quantas colunas existem, o tipo de dado de cada uma e se há valores nulos. É nessa etapa que identificamos colunas que precisarão de conversão de tipo e colunas com dados pendentes que exigirão tratamento.
#
# **2. Valores nulos**
# Colunas com valores ausentes precisam de uma decisão: preencher com a mediana, com a moda, com um valor padrão, ou remover os registros. Cada decisão tem impacto direto na qualidade da análise e deve ser documentada e justificada.
#
# **3. Estatísticas descritivas (df.describe())**
# Revela a distribuição de cada coluna numérica (mínimo, máximo, média e percentis). É aqui que são identificados valores impossíveis ou suspeitos, como tarifas negativas, distâncias zero e corridas sem passageiros, que serão tratados na etapa de limpeza.
#
# **4. Valores únicos nas colunas categóricas**
# Revela quantas categorias distintas existem em cada coluna de texto ou código, permitindo identificar inconsistências como categorias inválidas, erros de digitação ou códigos não documentados.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1500000 non-null  int64
#  1   tpep_pickup_datetime   1500000 non-null  object
#  2   tpep_dropoff_datetime  1500000 non-null  object
#  3   passenger_count        1500000 non-null  int64
#  4   trip_distance          1500000 non-null  float64
#  5   pickup_longitude       1500000 non-null  float64
#  6   pickup_latitude        1500000 non-null  float64
#  7   RatecodeID             1500000 non-null  int64
#  8   store_and_fwd_flag     1500000 non-null  object
#  9   dropoff_longitude      1500000 non-null  float64
#  10  dropoff_latitude       1500000 non-null  float64
#  11  payment_type           1500000 non-null  int64
#  12  fare_amount            1500000 non-null  float64
#  13  extra                  1500000 non-null  float64
#  14  mta_tax                1500000 non-null  float64
#  15  tip_amount             1500000 non-null  float64
#  16  tolls_amount           1500000 non-null  float64
#  17  improvement_surcharge  1500000 non-null  float64
#  18  total_amount           1500000 non-null  float64
#  19  mes_origem             1500000 non-null  object
# dtypes: float64(12), int64(4), object(4)
# memory usage: 228.9+ MB

# %%
print("Valores nulos por coluna:")
nulos = df.isnull().sum()
nulos_percentual = (nulos / len(df) * 100).round(2)

resumo_nulos = pd.DataFrame({
    'Nulos': nulos,
    '% do total': nulos_percentual
})

print(resumo_nulos[resumo_nulos['Nulos'] > 0])
# Out:
# Valores nulos por coluna:
# Empty DataFrame
# Columns: [Nulos, % do total]
# Index: []

# %%
colunas_criticas = ['passenger_count', 'trip_distance', 'fare_amount', 
                    'tip_amount', 'tolls_amount', 'total_amount',
                    'pickup_longitude', 'pickup_latitude',
                    'dropoff_longitude', 'dropoff_latitude']

df[colunas_criticas].describe().round(2)
# Out:
#        passenger_count  trip_distance  fare_amount  tip_amount  tolls_amount  \
# count       1500000.00     1500000.00   1500000.00  1500000.00    1500000.00
# mean              1.66           4.92        12.61        1.77          0.30
# std               1.32        2370.26       103.72        2.54          1.53
# min               0.00           0.00      -234.00      -11.43         -6.00
# 25%               1.00           1.00         6.50        0.00          0.00
# 50%               1.00           1.70         9.00        1.32          0.00
# 75%               2.00           3.10        14.00        2.35          0.00
# max               9.00     2900000.00    126348.88      500.00        785.54
#
#        total_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count    1500000.00        1500000.00       1500000.00         1500000.00
# mean          15.80            -72.84            40.12             -72.90
# std          104.02              9.10             5.01               8.84
# min         -234.80           -121.93             0.00            -121.93
# 25%            8.30            -73.99            40.74             -73.99
# 50%           11.76            -73.98            40.75             -73.98
# 75%           17.30            -73.97            40.77             -73.96
# max       126366.58              0.00            44.26               0.00
#
#        dropoff_latitude
# count        1500000.00
# mean              40.16
# std                4.87
# min                0.00
# 25%               40.73
# 50%               40.75
# 75%               40.77
# max               46.30

# %%
categoricas = ['payment_type', 'RatecodeID', 'store_and_fwd_flag', 'mes_origem']

for coluna in categoricas:
    print(f"\n{coluna}:", df[coluna].value_counts())
# Out:
# payment_type: payment_type
# 1    999293
# 2    493241
# 3      5516
# 4      1950
# Name: count, dtype: int64
#
# RatecodeID: RatecodeID
# 1     1461981
# 2       30466
# 5        4532
# 3        2348
# 4         627
# 99         32
# 6          14
# Name: count, dtype: int64
#
# store_and_fwd_flag: store_and_fwd_flag
# N    1491504
# Y       8496
# Name: count, dtype: int64
#
# mes_origem: mes_origem
# 01    500000
# 02    500000
# 03    500000
# Name: count, dtype: int64

# %% [markdown]
# ## Observações do Data Profiling
#
# **Valores nulos:** Nenhum valor nulo identificado em nenhuma coluna, resultado incomum em dados operacionais reais.
#
# **payment_type:** 4 categorias identificadas. Pela documentação oficial do TLC, apenas os tipos 1 (cartão de crédito) e 2 (dinheiro) representam corridas reais. Os tipos 3 (sem cobrança) e 4 (disputa de tarifa) totalizam 7.503 registros que serão removidos na etapa de limpeza, pois não representam corridas comerciais concluídas de forma convencional. Como o objetivo neste caso é analisar o padrão operacional e financeiro das corridas regulares de táxi em Nova York, manter esses registros introduziria ruído sistemático nos principais indicadores de negócio.
#
# **RatecodeID:** O código 99 aparece 37 vezes, mas não consta na documentação oficial, cujas categorias válidas vão de 1 a 6, sendo:
# 1- Tarifa padrão
# 2- JFK
# 3- Newark
# 4- Nassau/Westchester
# 5- Tarifa negociada
# 6- Corrida em grupo
# Por não ter definição oficial e representar menos de 0,003% da amostra, esses 37 registros serão removidos.
#
# **store_and_fwd_flag:** Essa coluna indica se o registro da corrida foi armazenado localmente no taxímetro antes de ser enviado ao servidor central, o que ocorre quando o veículo está em área sem cobertura de rede. Como 99,4% dos registros são N (envio direto) e os 8.649 registros Y não indicam problema de qualidade nos dados, a coluna não agrega valor analítico e será descartada para simplificar o dataset.
#
# **passenger_count:** Mínimo de zero: corridas sem passageiros são operacionalmente impossíveis e indicam falha no registro do taxímetro, portanto serão removidas. Máximo de 9 está dentro do limite legal para vans de taxi em NYC.
#
# **trip_distance:** Mínimo de 0 milhas (corrida que não saiu do lugar) e máximo de 284.000 milhas (equivalente a 11 voltas ao redor do mundo). Ambos são erros de registro, e será aplicado um filtro entre 0,1 e 100 milhas, cobringo o range operacional real de corridas na cidade.
#
# **fare_amount:** Valores negativos são fisicamente impossíveis em qualquer sistema de cobrança, e valores acima de 4.000 são extremamente suspeitos e configuram outliers. Serão mantidos apenas registros com tarifa entre 2,50 (valor mínimo oficial) e 500.
#
# **tip_amount / tolls_amount:** Gorjetas e pedágios negativos são impossíveis, indicam estornos ou erros de sistema registrados de forma incorreta, portanto serão filtrados valores menores que zero.
#
# **Coordenadas geográficas:** Nova York está localizada entre as longitudes -74,3 e -73,7 e as latitudes 40,4 e 40,9. Valores de longitude 0 (Meridiano de Greenwich) e latitude 0 (oceano Atlântico) confirmam falhas de GPS. Todos os registros com coordenadas fora do bounding box da cidade serão removidos.

# %% [markdown]
# ## Problemas identificados para tratamento
#
# **Conversão de datas:** As colunas tpep_pickup_datetime e tpep_dropoff_datetime estão armazenadas como texto, e precisam ser convertidas para o tipo datetime para permitir análises temporais como hora do dia, dia da semana e duração da corrida.
#
# **Remoção de registros inválidos:** payment_type 3 e 4, e RatecodeID 99 serão removidos pelos motivos descritos acima.
#
# **Descarte de colunas sem valor analítico:** store_and_fwd_flag será removida por não contribuir com nenhuma análise de negócio relevante.
#
# **Valores impossíveis em colunas numéricas:** A análise descritiva apontou a presença provável de valores que ferem restrições físicas e operacionais básicas, como tarifas negativas, distâncias zero ou negativas, corridas sem nenhum passageiro e gorjetas negativas. Cada um desses será investigado, quantificado e tratado com critério na etapa de limpeza, preservando o máximo de registros válidos possível.

# %% [markdown]
# ## Limpeza e tratamento dos dados
#
# Com base nos problemas identificados, esta etapa aplica um conjunto de transformações e filtros para garantir que apenas registros válidos e consistentes sejam utilizados nas análises. Cada decisão de limpeza é documentada e justificada.

# %%
# converter datas de texto para datetime

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

print(f"Tipo pickup: {df['tpep_pickup_datetime'].dtype}")
print(f"Tipo dropoff: {df['tpep_dropoff_datetime'].dtype}")
# Out:
# Tipo pickup: datetime64[ns]
# Tipo dropoff: datetime64[ns]

# %%
# calcular duração da viagem em minutos

df['duracao_min'] = (
    (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
)

print(f"Duração mínima: {df['duracao_min'].min():.1f} min")
print(f"Duração máxima: {df['duracao_min'].max():.1f} min")
print(f"Duração média: {df['duracao_min'].mean():.1f} min")
# Out:
# Duração mínima: -10124.4 min
# Duração máxima: 1439.9 min
# Duração média: 15.3 min

# %%
# componentes temporais

df['hora'] = df['tpep_pickup_datetime'].dt.hour
df['dia_semana'] = df['tpep_pickup_datetime'].dt.day_name()
df['dia_semana_num'] = df['tpep_pickup_datetime'].dt.dayofweek  # Segunda=0, Domingo=6
df['mes'] = df['tpep_pickup_datetime'].dt.month
df['dia_mes'] = df['tpep_pickup_datetime'].dt.day

# %%
# descartar colunas sem valor analítico

colunas_descartar = ['store_and_fwd_flag']
df = df.drop(columns=colunas_descartar)

# %%
# registrar tamanho original antes da limpeza

registros_originais = len(df)
print(f"Registros antes da limpeza: {registros_originais:,}")
# Out:
# Registros antes da limpeza: 1,500,000

# %%
# aplicação dos filtros

df_limpo = df[
    # passageiros: mínimo 1, máximo 9
    (df['passenger_count'] >= 1) & (df['passenger_count'] <= 9) &

    # distância: mínimo 0.1 milhas, máximo 100 milhas
    (df['trip_distance'] >= 0.1) & (df['trip_distance'] <= 100) &

    # valor da corrida: mínimo $2.50, máximo $500
    (df['fare_amount'] >= 2.50) & (df['fare_amount'] <= 500) &

    # gorjeta: sem valores negativos
    (df['tip_amount'] >= 0) &

    # pedágios: sem valores negativos
    (df['tolls_amount'] >= 0) &

    # valor total: mínimo $2.50, máximo $500
    (df['total_amount'] >= 2.50) & (df['total_amount'] <= 500) &

    # duração: mínimo 1 minuto, máximo 180 minutos
    (df['duracao_min'] >= 1) & (df['duracao_min'] <= 180) &

    # payment type: apenas formas de pagamento válidas (1 ou 2)
    (df['payment_type'].isin([1, 2])) &

    # RatecodeID: apenas códigos válidos (1 a 6)
    (df['RatecodeID'] >= 1) & (df['RatecodeID'] <= 6) &

    # coordenadas: dentro dos limites aproximados de NYC
    (df['pickup_longitude'] >= -74.3) & (df['pickup_longitude'] <= -73.7) &
    (df['pickup_latitude'] >= 40.4) & (df['pickup_latitude'] <= 40.9) &
    (df['dropoff_longitude'] >= -74.3) & (df['dropoff_longitude'] <= -73.7) &
    (df['dropoff_latitude'] >= 40.4) & (df['dropoff_latitude'] <= 40.9) &

    # filtrar apenas os meses de janeiro a março de 2016
    (df['mes_origem'].isin(['01', '02', '03']))
]

print(f"Registros originais: {registros_originais:,}")
print(f"Registros após limpeza: {len(df_limpo):,}")
print(f"Registros removidos: {registros_originais - len(df_limpo):,}")
print(f"Taxa de aproveitamento: {len(df_limpo)/registros_originais*100:.1f}%")
# Out:
# Registros originais: 1,500,000
# Registros após limpeza: 1,455,067
# Registros removidos: 44,933
# Taxa de aproveitamento: 97.0%

# %%
# detalhamento individual dos filtros

filtros = {
    'passenger_count inválido'    : df[(df['passenger_count'] < 1) | (df['passenger_count'] > 6)],
    'trip_distance inválida'      : df[(df['trip_distance'] <= 0.1) | (df['trip_distance'] > 100)],
    'fare_amount inválido'        : df[(df['fare_amount'] < 2.50) | (df['fare_amount'] > 500)],
    'tip_amount negativo'         : df[df['tip_amount'] < 0],
    'tolls_amount negativo'       : df[df['tolls_amount'] < 0],
    'total_amount inválido'       : df[(df['total_amount'] < 2.50) | (df['total_amount'] > 500)],
    'duração inválida'            : df[(df['duracao_min'] < 1) | (df['duracao_min'] > 180)],
    'payment_type inválido'       : df[~df['payment_type'].isin([1, 2])],
    'RatecodeID inválido'         : df[~df['RatecodeID'].isin([1, 2, 3, 4, 5, 6])],
    'coordenadas fora de NYC'     : df[
        ~df['pickup_longitude'].between(-74.3, -73.7) |
        ~df['pickup_latitude'].between(40.4, 40.9) |
        ~df['dropoff_longitude'].between(-74.3, -73.7) |
        ~df['dropoff_latitude'].between(40.4, 40.9)
    ],
    'data fora do período'        : df[
        (df['tpep_pickup_datetime'].dt.year != 2016) |
        (~df['tpep_pickup_datetime'].dt.month.isin([1, 2, 3]))
    ],
}

print("Impacto individual de cada filtro:")
print(f"{'Filtro':<35} {'Registros removidos':>20} {'% do total':>12}")
print("-" * 70)
for nome, subset in filtros.items():
    qtd = len(subset)
    pct = qtd / registros_originais * 100
    print(f"{nome:<35} {qtd:>20,} {pct:>11.2f}%")
# Out:
# Impacto individual de cada filtro:
# Filtro                               Registros removidos   % do total
# ----------------------------------------------------------------------
# passenger_count inválido                              20        0.00%
# trip_distance inválida                             4,668        0.31%
# fare_amount inválido                                 266        0.02%
# tip_amount negativo                                    0        0.00%
# tolls_amount negativo                                  1        0.00%
# total_amount inválido                                234        0.02%
# duração inválida                                   4,876        0.33%
# payment_type inválido                                  0        0.00%
# RatecodeID inválido                                    0        0.00%
# coordenadas fora de NYC                           15,095        1.01%
# data fora do período                                   0        0.00%

# %%
# salvar dataset limpo

df_limpo.to_parquet('../data/nyc_taxi_limpo.parquet', index=False)

print(f"Registros: {len(df_limpo):,}")
print(f"Colunas: {df_limpo.shape[1]}")
# Out:
# Registros: 1,455,067
# Colunas: 25

# %% [markdown]
# ## Análise exploratória
#
# Depois da limpeza e validação do dataset, são respondidas as perguntas de negócio definidas no início do projeto.

# %%
# carregar dataset limpo para análise

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

sns.set_theme(style="darkgrid")
plt.rcParams['figure.figsize'] = (13, 5)
plt.rcParams['font.size'] = 12

# carregar dataset limpo
df = pd.read_parquet('../data/nyc_taxi_limpo.parquet')

print(f"Dataset limpo carregado")

df.head()
# Out:
# Dataset limpo carregado
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:06   2016-01-01 00:07:14                1
# 1         2  2016-01-01 00:00:32   2016-01-01 00:13:20                5
# 2         2  2016-01-01 00:01:19   2016-01-01 00:03:12                2
# 3         1  2016-01-01 00:01:20   2016-01-01 00:07:24                2
# 4         2  2016-01-01 00:01:23   2016-01-01 00:09:22                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.38        -73.994843        40.718498           1
# 1           3.60        -73.996948        40.720501           1
# 2           0.37        -73.997696        40.737659           1
# 3           1.00        -73.967552        40.756859           1
# 4           1.11        -73.998611        40.738171           1
#
#    dropoff_longitude  dropoff_latitude  ...  tolls_amount  \
# 0         -73.989807         40.734230  ...           0.0
# 1         -73.958183         40.721790  ...           0.0
# 2         -73.991241         40.734982  ...           0.0
# 3         -73.978310         40.748611  ...           0.0
# 4         -73.994591         40.750549  ...           0.0
#
#    improvement_surcharge  total_amount  mes_origem  duracao_min  hora  \
# 0                    0.3          9.96          01     7.133333     0
# 1                    0.3         17.76          01    12.800000     0
# 2                    0.3          4.80          01     1.883333     0
# 3                    0.3          8.75          01     6.066667     0
# 4                    0.3          9.96          01     7.983333     0
#
#    dia_semana  dia_semana_num mes  dia_mes
# 0      Friday               4   1        1
# 1      Friday               4   1        1
# 2      Friday               4   1        1
# 3      Friday               4   1        1
# 4      Friday               4   1        1
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Perfil geral das corridas
#
# Principais métricas operacionais e financeiras do 1º trimestre de 2016.

# %%
print(f"\nTotal de corridas analisadas: {len(df):,}")

print(f"\nTEMPO")
print(f"Duração mínima: {df['duracao_min'].min():.1f} min")
print(f"Duração máxima: {df['duracao_min'].max():.1f} min")
print(f"Duração média: {df['duracao_min'].mean():.1f} min")
print(f"Duração mediana: {df['duracao_min'].median():.1f} min")

print(f"\nDISTÂNCIA")
print(f"Distância mínima: {df['trip_distance'].min():.2f} milhas")
print(f"Distância máxima: {df['trip_distance'].max():.2f} milhas")
print(f"Distância média: {df['trip_distance'].mean():.2f} milhas")
print(f"Distância mediana: {df['trip_distance'].median():.2f} milhas")

print(f"\nFINANCEIRO")
print(f"Tarifa mínima: $ {df['fare_amount'].min():.2f}")
print(f"Tarifa máxima: $ {df['fare_amount'].max():.2f}")
print(f"Tarifa média: $ {df['fare_amount'].mean():.2f}")
print(f"Total mínimo cobrado: $ {df['total_amount'].min():.2f}")
print(f"Total máximo cobrado: $ {df['total_amount'].max():.2f}")
print(f"Total médio cobrado: $ {df['total_amount'].mean():.2f}")
print(f"Gorjeta mínima: $ {df['tip_amount'].min():.2f}")
print(f"Gorjeta máxima: $ {df['tip_amount'].max():.2f}")
print(f"Gorjeta média: $ {df['tip_amount'].mean():.2f}")
print(f"Receita total estimada: $ {df['total_amount'].sum():,.0f}")

print(f"\nPASSAGEIROS")
print(f"Mínimo de passageiros: {df['passenger_count'].min()}")
print(f"Máximo de passageiros: {df['passenger_count'].max()}")
print(f"Média de passageiros: {df['passenger_count'].mean():.1f}")
print(f"Corridas solo (1 passageiro): {(df['passenger_count']==1).sum()/len(df)*100:.1f}%")

print(f"\nPAGAMENTO")
print(f"Pagamento com cartão: {(df['payment_type']==1).sum()/len(df)*100:.1f}%")
print(f"Pagamento em dinheiro: {(df['payment_type']==2).sum()/len(df)*100:.1f}%")
# Out:
# Total de corridas analisadas: 1,455,067
#
# TEMPO
# Duração mínima: 1.0 min
# Duração máxima: 178.7 min
# Duração média: 13.4 min
# Duração mediana: 10.7 min
#
# DISTÂNCIA
# Distância mínima: 0.10 milhas
# Distância máxima: 86.52 milhas
# Distância média: 2.90 milhas
# Distância mediana: 1.70 milhas
#
# FINANCEIRO
# Tarifa mínima: $ 2.50
# Tarifa máxima: $ 350.00
# Tarifa média: $ 12.42
# Total mínimo cobrado: $ 3.30
# Total máximo cobrado: $ 400.00
# Total médio cobrado: $ 15.61
# Gorjeta mínima: $ 0.00
# Gorjeta máxima: $ 350.00
# Gorjeta média: $ 1.77
# Receita total estimada: $ 22,719,219
#
# PASSAGEIROS
# Mínimo de passageiros: 1
# Máximo de passageiros: 9
# Média de passageiros: 1.7
# Corridas solo (1 passageiro): 71.0%
#
# PAGAMENTO
# Pagamento com cartão: 67.2%
# Pagamento em dinheiro: 32.8%

# %% [markdown]
# ### Padrões temporais
#
# Análise da distribuição de corridas ao longo do tempo (por hora do dia, dia da semana e mês). Revela os picos de demanda e sazonalidade do serviço.

# %%
# corridas por hora do dia

corridas_hora = df.groupby('hora').size().reset_index(name='corridas')

fig, ax = plt.subplots(figsize=(13, 5))
cores = ['tomato' if h in corridas_hora.nlargest(3, 'corridas')['hora'].values 
         else 'steelblue' for h in corridas_hora['hora']]
bars = ax.bar(corridas_hora['hora'], corridas_hora['corridas'],
              color=cores, edgecolor='white', linewidth=0.5)

ax.set_title('Volume de Corridas por Hora do Dia — Q1 2016', 
             fontsize=14, fontweight='bold')
ax.set_xlabel('Hora do Dia')
ax.set_ylabel('Número de Corridas')
ax.set_xticks(range(0, 24))
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

hora_pico = corridas_hora.loc[corridas_hora['corridas'].idxmax(), 'hora']
print(f"Hora de maior demanda: {hora_pico}h com {corridas_hora['corridas'].max():,} corridas")
print(f"Hora de menor demanda: {corridas_hora.loc[corridas_hora['corridas'].idxmin(), 'hora']}h")
# Out:
# Hora de maior demanda: 18h com 92,594 corridas
# Hora de menor demanda: 5h

# %%
# corridas por dia da semana

ordem_dias = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
labels_dias = ['Seg','Ter','Qua','Qui','Sex','Sáb','Dom']

corridas_dia = df.groupby('dia_semana').size().reindex(ordem_dias).reset_index(name='corridas')

fig, ax = plt.subplots(figsize=(10, 5))
cores = ['tomato' if d in ['Friday','Saturday'] else 'steelblue' for d in ordem_dias]
ax.bar(labels_dias, corridas_dia['corridas'], color=cores, edgecolor='white')
ax.set_title('Volume de Corridas por Dia da Semana — Q1 2016', 
             fontsize=14, fontweight='bold')
ax.set_xlabel('Dia da Semana')
ax.set_ylabel('Número de Corridas')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

print("\nCorridas por dia da semana:")
for dia, label in zip(ordem_dias, labels_dias):
    qtd = corridas_dia.loc[corridas_dia['dia_semana']==dia, 'corridas'].values[0]
    print(f"   {label}: {qtd:,}")
# Out:
# Corridas por dia da semana:
#    Seg: 187,590
#    Ter: 202,102
#    Qua: 210,656
#    Qui: 220,016
#    Sex: 226,987
#    Sáb: 215,534
#    Dom: 192,182

# %%
# resumo mensal

meses_map = {1: 'Janeiro', 2: 'Fevereiro', 3: 'Março'}

corridas_mes = df.groupby('mes').agg(
    corridas      = ('total_amount', 'count'),
    receita_total = ('total_amount', 'sum'),
    ticket_medio  = ('total_amount', 'mean')
).reset_index()
corridas_mes['mes_nome'] = corridas_mes['mes'].map(meses_map)

fig, ax1 = plt.subplots(figsize=(10, 5))
ax2 = ax1.twinx()

ax1.bar(corridas_mes['mes_nome'], corridas_mes['corridas'],
        color='steelblue', alpha=0.7, label='Corridas')
ax2.plot(corridas_mes['mes_nome'], corridas_mes['ticket_medio'],
         color='tomato', marker='o', linewidth=2.5, label='Ticket Médio ($)')

ax1.set_title('Evolução Mensal — Volume de Corridas e Ticket Médio', 
              fontsize=14, fontweight='bold')
ax1.set_ylabel('Número de Corridas')
ax2.set_ylabel('Ticket Médio ($)')
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.tight_layout()
plt.show()

print("\nResumo mensal:")
print(corridas_mes[['mes_nome','corridas','receita_total','ticket_medio']].to_string(index=False))
# ticket médio: valor médio cobrado por corrida em cada mês
# Out:
# Resumo mensal:
#  mes_nome  corridas  receita_total  ticket_medio
#   Janeiro    485029     7513600.43     15.491033
# Fevereiro    484972     7497971.14     15.460627
#     Março    485066     7707647.59     15.889895

# %% [markdown]
# ### Padrão financeiro
#
# Distribuição de tarifas, gorjetas e formas de pagamento, revela o perfil financeiro das corridas e o comportamento dos passageiros em relação à gorjeta.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(df['fare_amount'], bins=60, color='steelblue',
             edgecolor='white', linewidth=0.5)
axes[0].set_title('Distribuição de Tarifas', fontweight='bold')
axes[0].set_xlabel('Tarifa ($)')
axes[0].set_ylabel('Frequência')
axes[0].xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:.0f}'))
axes[0].yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))

axes[1].hist(df['tip_amount'][df['tip_amount'] > 0], bins=60, color='tomato',
             edgecolor='white', linewidth=0.5)
axes[1].set_title('Distribuição de Gorjetas (excl. zeros)', fontweight='bold')
axes[1].set_xlabel('Gorjeta ($)')
axes[1].set_ylabel('Frequência')
axes[1].xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:.0f}'))
axes[1].yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))

plt.suptitle('Perfil Financeiro das Corridas — Q1 2016', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

pct_gorjeta = (df['tip_amount'] > 0).sum() / len(df) * 100
print(f"Corridas com gorjeta: {pct_gorjeta:.1f}%")
print(f"Gorjeta média (com gorjeta): $ {df[df['tip_amount']>0]['tip_amount'].mean():.2f}")
print(f"Gorjeta média (geral): $ {df['tip_amount'].mean():.2f}")

print(f"   fare_amount  — mínimo: ${df['fare_amount'].min():.2f}  |  máximo: ${df['fare_amount'].max():.2f}  |  média: ${df['fare_amount'].mean():.2f}")
print(f"   tip_amount   — mínimo: ${df['tip_amount'].min():.2f}  |  máximo: ${df['tip_amount'].max():.2f}  |  média: ${df['tip_amount'].mean():.2f}")
print(f"   total_amount — mínimo: ${df['total_amount'].min():.2f}  |  máximo: ${df['total_amount'].max():.2f}  |  média: ${df['total_amount'].mean():.2f}")
# Out:
# Corridas com gorjeta: 64.9%
# Gorjeta média (com gorjeta): $ 2.73
# Gorjeta média (geral): $ 1.77
#    fare_amount  — mínimo: $2.50  |  máximo: $350.00  |  média: $12.42
#    tip_amount   — mínimo: $0.00  |  máximo: $350.00  |  média: $1.77
#    total_amount — mínimo: $3.30  |  máximo: $400.00  |  média: $15.61

# %%
# gorjeta por forma de pagamento

gorjeta_pag = df.groupby('payment_type').agg(
    gorjeta_media = ('tip_amount', 'mean'),
    corridas      = ('tip_amount', 'count'),
    pct_com_gorjeta = ('tip_amount', lambda x: (x > 0).mean() * 100)
).reset_index()
gorjeta_pag['payment_type'] = gorjeta_pag['payment_type'].map({1:'Cartão', 2:'Dinheiro'})

fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(gorjeta_pag['payment_type'], gorjeta_pag['gorjeta_media'],
              color=['steelblue','tomato'], edgecolor='white', width=0.4)
ax.set_title('Gorjeta Média por Forma de Pagamento', fontsize=14, fontweight='bold')
ax.set_ylabel('Gorjeta Média ($)')
for bar, val in zip(bars, gorjeta_pag['gorjeta_media']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02,
            f'${val:.2f}', ha='center', fontweight='bold', fontsize=12)
plt.tight_layout()
plt.show()

print("\nDetalhamento por forma de pagamento:")
print(gorjeta_pag.to_string(index=False))
# Out:
# Detalhamento por forma de pagamento:
# payment_type  gorjeta_media  corridas  pct_com_gorjeta
#       Cartão       2.631859    977949        96.529778
#     Dinheiro       0.000043    477118         0.001677

# %% [markdown]
# ### Padrões geográficos
#
# Distribuição geográfica das corridas usando as coordenadas de latitude e longitude, identifica as regiões de maior concentração de embarques e desembarques.

# %%
# mapa de calor de embarques

amostra_mapa = df.sample(50_000, random_state=42)

fig = px.density_mapbox(
    amostra_mapa,
    lat='pickup_latitude',
    lon='pickup_longitude',
    radius=2,
    center=dict(lat=40.75, lon=-73.98),
    zoom=10,
    mapbox_style='carto-darkmatter',
    title='Mapa de Calor — Embarques (Pickup) — Q1 2016',
    color_continuous_scale='Inferno',
    height=600
)
fig.show()
# Out:
# /var/folders/95/bfmf5w9s025550r0hnkcj5p40000gn/T/ipykernel_34788/1933081316.py:5: DeprecationWarning: *density_mapbox* is deprecated! Use *density_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.density_mapbox(

# %%
df['regiao'] = df['pickup_latitude'].round(2).astype(str) + ',' + \
               df['pickup_longitude'].round(2).astype(str)

top_regioes = df.groupby('regiao').agg(
    corridas      = ('total_amount', 'count'),
    receita_total = ('total_amount', 'sum'),
    ticket_medio  = ('total_amount', 'mean')
).reset_index().sort_values('corridas', ascending=False).head(10)

print("🗺️  Top 10 regiões por volume de corridas:")
print(top_regioes.to_string(index=False))
# Out:
# 🗺️  Top 10 regiões por volume de corridas:
#       regiao  corridas  receita_total  ticket_medio
# 40.76,-73.97     90874     1238965.01     13.633878
# 40.75,-73.99     90311     1260542.17     13.957792
# 40.76,-73.98     79565     1187775.13     14.928362
# 40.75,-73.98     73511     1033660.90     14.061309
# 40.74,-73.99     67057      908596.92     13.549621
# 40.76,-73.99     66646      957840.63     14.372065
# 40.73,-73.99     53108      735273.61     13.844875
# 40.77,-73.96     52009      635133.78     12.211998
# 40.77,-73.98     47002      637754.67     13.568671
#  40.73,-74.0     44569      623427.73     13.987923

# %% [markdown]
# ### Fatores que influenciam a gorjeta
#
# Relação da gorjeta com distância, horário, dia da semana e forma de pagamento.

# %%
# gorjeta por hora do dia

gorjeta_hora = df[df['payment_type']==1].groupby('hora').agg(
    gorjeta_media = ('tip_amount', 'mean'),
    pct_gorjeta   = ('tip_amount', lambda x: (x>0).mean()*100)
).reset_index()

fig, ax1 = plt.subplots(figsize=(13, 5))
ax2 = ax1.twinx()

ax1.bar(gorjeta_hora['hora'], gorjeta_hora['gorjeta_media'],
        color='steelblue', alpha=0.7, label='Gorjeta Média ($)')
ax2.plot(gorjeta_hora['hora'], gorjeta_hora['pct_gorjeta'],
         color='tomato', marker='o', linewidth=2, label='% Corridas com Gorjeta')

ax1.set_title('Gorjeta por Hora do Dia — Pagamentos com Cartão', 
              fontsize=14, fontweight='bold')
ax1.set_xlabel('Hora do Dia')
ax1.set_ylabel('Gorjeta Média ($)')
ax2.set_ylabel('% Corridas com Gorjeta')
ax1.set_xticks(range(0, 24))
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# gorjeta por dia da semana

gorjeta_dia = df[df['payment_type']==1].groupby('dia_semana').agg(
    gorjeta_media = ('tip_amount', 'mean')
).reindex(ordem_dias).reset_index()
gorjeta_dia['label'] = labels_dias

fig, ax = plt.subplots(figsize=(10, 5))
cores = ['tomato' if d in ['Friday','Saturday'] else 'steelblue' for d in ordem_dias]
bars = ax.bar(gorjeta_dia['label'], gorjeta_dia['gorjeta_media'],
              color=cores, edgecolor='white')
ax.set_title('Gorjeta Média por Dia da Semana — Pagamentos com Cartão',
             fontsize=14, fontweight='bold')
ax.set_ylabel('Gorjeta Média ($)')
for bar, val in zip(bars, gorjeta_dia['gorjeta_media']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f'${val:.2f}', ha='center', fontsize=10)
plt.tight_layout()
plt.show()

# %%
# correlação entre variáveis

colunas_corr = ['fare_amount', 'trip_distance', 'duracao_min',
                'passenger_count', 'tip_amount', 'total_amount']

corr = df[colunas_corr].corr().round(2)

fig, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, linewidths=0.5, ax=ax)
ax.set_title('Matriz de Correlação — Variáveis Numéricas',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print("\nCorrelação com tip_amount:")
print(corr['tip_amount'].sort_values(ascending=False))
# Out:
# Correlação com tip_amount:
# tip_amount         1.00
# total_amount       0.72
# fare_amount        0.59
# trip_distance      0.58
# duracao_min        0.51
# passenger_count   -0.00
# Name: tip_amount, dtype: float64
